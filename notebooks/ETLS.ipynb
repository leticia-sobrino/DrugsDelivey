# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # ETLS

# %% [markdown]
# En este notbook se proporcionarán los pasos realizados para la limpieza y analisis de los datasets con los que vamos a partir para el desarrollo del proyecto. El fin es conseguir un dataset limpio y sencillo con el que poder jugar y así poder desarrollar nuestra idea de proyecto.

# %% [markdown]
# ## Centros médicos Madrid

# %%
centros_medicos = pd.read_csv("../data/centros_medicos_madrid.csv", encoding='latin-1', sep=';', error_bad_lines=False)
centros_medicos.head()
# Out:
#        PK                                             NOMBRE  \
# 0  134929  Centro Concertado de Atención a las Adicciones...
# 1   53123  Centro Concertado de Atención a las Adicciones...
# 2   11867  Centro de Atención a las Adicciones (CAD) de A...
# 3   11887  Centro de Atención a las Adicciones (CAD) de H...
# 4   11862  Centro de Atención a las Adicciones (CAD) de L...
#
#                                  DESCRIPCION-ENTIDAD  \
# 0  El CCAD Cáritas que forma parte de la red del ...
# 1  El CCAD  Casa de Campo que forma parte de la r...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                              HORARIO  \
# 0  De lunes a viernes mañanas de 9 a 14 horas, ta...
# 1                 De lunes a viernes de 9 a 17 horas
# 2  Horario ordinario:De lunes a jueves de 8 a 20:...
# 3  Horario ordinario:De lunes a jueves de 8 a 20:...
# ...

# %%
centros_medicos.shape
# Out:
# (270, 31)

# %%
centros_medicos.keys()
# Out:
# Index(['PK', 'NOMBRE', 'DESCRIPCION-ENTIDAD', 'HORARIO', 'EQUIPAMIENTO',
#        'TRANSPORTE', 'DESCRIPCION', 'ACCESIBILIDAD', 'CONTENT-URL',
#        'NOMBRE-VIA', 'CLASE-VIAL', 'TIPO-NUM', 'NUM', 'PLANTA', 'PUERTA',
#        'ESCALERAS', 'ORIENTACION', 'LOCALIDAD', 'PROVINCIA', 'CODIGO-POSTAL',
#        'BARRIO', 'DISTRITO', 'COORDENADA-X', 'COORDENADA-Y', 'LATITUD',
#        'LONGITUD', 'TELEFONO', 'FAX', 'EMAIL', 'TIPO', 'Unnamed: 30'],
#       dtype='object')

# %%
centros_medicos.isnull().sum()
# Out:
# PK                       0
# NOMBRE                   0
# DESCRIPCION-ENTIDAD    258
# HORARIO                 65
# EQUIPAMIENTO            87
# TRANSPORTE               1
# DESCRIPCION            214
# ACCESIBILIDAD            0
# CONTENT-URL              0
# NOMBRE-VIA               0
# CLASE-VIAL               0
# TIPO-NUM                 0
# NUM                      4
# PLANTA                 256
# PUERTA                 268
# ESCALERAS              270
# ORIENTACION            250
# LOCALIDAD                0
# PROVINCIA                0
# CODIGO-POSTAL            1
# BARRIO                   5
# DISTRITO                 0
# COORDENADA-X             0
# COORDENADA-Y             0
# LATITUD                  0
# LONGITUD                 0
# TELEFONO                 0
# FAX                    228
# EMAIL                  216
# TIPO                     0
# Unnamed: 30              0
# dtype: int64

# %% [markdown]
# * Como vemos hay muchas columnas que tienen mucshísimos valores nulos y las vamos a tener que eliminar
# * La eliminación de estas columnas no influye en absoluto con el desarrollo de nuestro proyecto porque esa información no es relevante para conseguir el fin de este trabajo
# * Por lo tanto eliminaremos las siguientes diez columnas:
#     - DESCRIPCION-ENTIDAD
#     - HORARIO
#     - EQUIPAMIENTO
#     - DESCRIPCION
#     - PLANTA
#     - PUERTA
#     - ESCALERAS
#     - ORIENTACION
#     - FAX
#     - EMAIL

# %%
centros_medicos = centros_medicos.drop(['DESCRIPCION-ENTIDAD', 'HORARIO', 'EQUIPAMIENTO', 'DESCRIPCION', 'PLANTA', 'PUERTA', 'ESCALERAS', 'ORIENTACION', 'FAX', 'EMAIL'], axis=1)
centros_medicos.head()
# Out:
#        PK                                             NOMBRE  \
# 0  134929  Centro Concertado de Atención a las Adicciones...
# 1   53123  Centro Concertado de Atención a las Adicciones...
# 2   11867  Centro de Atención a las Adicciones (CAD) de A...
# 3   11887  Centro de Atención a las Adicciones (CAD) de H...
# 4   11862  Centro de Atención a las Adicciones (CAD) de L...
#
#                                           TRANSPORTE  ACCESIBILIDAD  \
# 0  Bus: 9, 73, N2Metro: Alfonso XIII (L4), Prospe...              1
# 1  Bus: 31, 33, 36, 39, 65, 138Metro:Puerta del A...              1
# 2  Bus: 6 , 8 , 18 , 19 , 22 , 45 , 47 , 76 , 78 ...              1
# 3  Bus: 73, 87, 104, 112, 120, 125, 153, 172Metro...              1
# 4  Bus: 25 , 31, 138Metro: Laguna (L 6), Casa de ...              1
#
#                                          CONTENT-URL       NOMBRE-VIA  \
# 0  http://www.madrid.es/sites/v/index.jsp?vgnextc...  SANTA HORTENSIA
# ...

# %%
centros_medicos.isnull().sum()
# Out:
# PK               0
# NOMBRE           0
# TRANSPORTE       1
# ACCESIBILIDAD    0
# CONTENT-URL      0
# NOMBRE-VIA       0
# CLASE-VIAL       0
# TIPO-NUM         0
# NUM              4
# LOCALIDAD        0
# PROVINCIA        0
# CODIGO-POSTAL    1
# BARRIO           5
# DISTRITO         0
# COORDENADA-X     0
# COORDENADA-Y     0
# LATITUD          0
# LONGITUD         0
# TELEFONO         0
# TIPO             0
# Unnamed: 30      0
# dtype: int64

# %%
centros_medicos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PK             270 non-null    int64
#  1   NOMBRE         270 non-null    object
#  2   TRANSPORTE     269 non-null    object
#  3   ACCESIBILIDAD  270 non-null    int64
#  4   CONTENT-URL    270 non-null    object
#  5   NOMBRE-VIA     270 non-null    object
#  6   CLASE-VIAL     270 non-null    object
#  7   TIPO-NUM       270 non-null    object
#  8   NUM            266 non-null    float64
#  9   LOCALIDAD      270 non-null    object
#  10  PROVINCIA      270 non-null    object
#  11  CODIGO-POSTAL  269 non-null    float64
#  12  BARRIO         265 non-null    object
#  13  DISTRITO       270 non-null    object
#  14  COORDENADA-X   270 non-null    int64
#  15  COORDENADA-Y   270 non-null    int64
#  16  LATITUD        270 non-null    object
# ...

# %% [markdown]
# ### Estudio profundo de los datos de cada columna

# %%
# Concatenar con tipo de via y nº para obtenter la dirección completa en solamente una columna
centros_medicos['NOMBRE-VIA']
# Out:
# 0      SANTA HORTENSIA
# 1             PORTUGAL
# 2              CHOPERA
# 3               MINAYA
# 4             CAMARENA
#             ...
# 265     CANDIDO MATEOS
# 266          AGUILEÑAS
# 267                REY
# 268            MONTESA
# 269       ARTURO SORIA
# Name: NOMBRE-VIA, Length: 270, dtype: object

# %%
# Concatenar con nombre de la vía via y nº para obtenter la dirección completa en solamente una columna
centros_medicos['CLASE-VIAL']
# Out:
# 0        CALLE
# 1      AVENIDA
# 2        PASEO
# 3        CALLE
# 4        CALLE
#         ...
# 265      CALLE
# 266      CALLE
# 267      PASEO
# 268      CALLE
# 269      CALLE
# Name: CLASE-VIAL, Length: 270, dtype: object

# %%
# Vamos a eliminar esta columna, información irrelevante para nuestro proyecto 
centros_medicos['TIPO-NUM'].unique()
# Out:
# array(['V', 'NUM', 'T'], dtype=object)

# %%
# Concatenar con tipo de via y nombre de la vía para obtenter la dirección completa en solamente una columna
centros_medicos['NUM']
# Out:
# 0        1.0
# 1        0.0
# 2       12.0
# 3        7.0
# 4       10.0
#        ...
# 265     11.0
# 266      1.0
# 267      NaN
# 268     22.0
# 269    103.0
# Name: NUM, Length: 270, dtype: float64

# %%
# Podemos eliminar esta columna ya que TODAS SON de madrid
centros_medicos['LOCALIDAD'].unique()
# Out:
# array(['MADRID'], dtype=object)

# %%
# Podemos eliminarla ya que TODAS SON de madrid
centros_medicos['PROVINCIA'].unique()
# Out:
# array(['MADRID'], dtype=object)

# %%
# QUITAR LOS CEROS
centros_medicos['CODIGO-POSTAL']
# Out:
# 0      28002.0
# 1      28011.0
# 2      28045.0
# 3      28043.0
# 4      28047.0
#         ...
# 265    28035.0
# 266    28029.0
# 267    28008.0
# 268    28006.0
# 269    28043.0
# Name: CODIGO-POSTAL, Length: 270, dtype: float64

# %%
# Vamos a eliminar esta columna, nos vamos a quedr solmente con el distrito
centros_medicos['BARRIO']
# Out:
# 0            PROSPERIDAD
# 1       PUERTA DEL ANGEL
# 2                CHOPERA
# 3               CANILLAS
# 4                 ALUCHE
#              ...
# 265          PEÑA GRANDE
# 266             ALMENARA
# 267            ARGUELLES
# 268                LISTA
# 269    SAN JUAN BAUTISTA
# Name: BARRIO, Length: 270, dtype: object

# %%
centros_medicos['DISTRITO']
# Out:
# 0                CHAMARTIN
# 1                   LATINA
# 2               ARGANZUELA
# 3                HORTALEZA
# 4                   LATINA
#               ...
# 265    FUENCARRAL-EL PARDO
# 266                 TETUAN
# 267        MONCLOA-ARAVACA
# 268              SALAMANCA
# 269          CIUDAD LINEAL
# Name: DISTRITO, Length: 270, dtype: object

# %%
centros_medicos.TIPO[0]
# Out:
# '/contenido/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes'

# %% [markdown]
# ### Eliminación de las columnas con datos irrelevantes para el desarrollo de este proyecto

# %%
centros_medicos = centros_medicos.drop(['PK', 'TRANSPORTE', 'ACCESIBILIDAD', 'CONTENT-URL', 'TIPO-NUM', 'LOCALIDAD', 'PROVINCIA', 'BARRIO', 'TELEFONO'], axis=1)
centros_medicos.head()
# Out:
#                                               NOMBRE       NOMBRE-VIA  \
# 0  Centro Concertado de Atención a las Adicciones...  SANTA HORTENSIA
# 1  Centro Concertado de Atención a las Adicciones...         PORTUGAL
# 2  Centro de Atención a las Adicciones (CAD) de A...          CHOPERA
# 3  Centro de Atención a las Adicciones (CAD) de H...           MINAYA
# 4  Centro de Atención a las Adicciones (CAD) de L...         CAMARENA
#
#   CLASE-VIAL   NUM  CODIGO-POSTAL    DISTRITO  COORDENADA-X  COORDENADA-Y  \
# 0      CALLE   1.0        28002.0   CHAMARTIN        443159       4477482
# 1    AVENIDA   0.0        28011.0      LATINA        438577       4474219
# 2      PASEO  12.0        28045.0  ARGANZUELA        440757       4471619
# 3      CALLE   7.0        28043.0   HORTALEZA        446072       4479929
# 4      CALLE  10.0        28047.0      LATINA        435820       4471982
#
#                   LATITUD                 LONGITUD  \
# ...

# %%
centros_medicos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NOMBRE         270 non-null    object
#  1   NOMBRE-VIA     270 non-null    object
#  2   CLASE-VIAL     270 non-null    object
#  3   NUM            266 non-null    float64
#  4   CODIGO-POSTAL  269 non-null    float64
#  5   DISTRITO       270 non-null    object
#  6   COORDENADA-X   270 non-null    int64
#  7   COORDENADA-Y   270 non-null    int64
#  8   LATITUD        270 non-null    object
#  9   LONGITUD       270 non-null    object
#  10  TIPO           270 non-null    object
#  11  Unnamed: 30    270 non-null    object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 25.4+ KB

# %% [markdown]
# #### Concatenamos columnas.
# Pasos a seguir:
#
#     1. Primero cambiaremos los valores nulos por un cero
#     2. Tranformaremos la columa de float a string
#     3. Concatenaremos las columnas: Clase de via, Nombre de via y nº de via
#     3. La del codigo postal aún no la junto porque tengo una idea (me gustaria que en la API con tan solo poner el codigo postas en vez de la latitud y longitud funcionara y te devolviera los tiempos, la distancia y la ruta)

# %%
centros_medicos.isnull().sum()
# Out:
# NOMBRE           0
# NOMBRE-VIA       0
# CLASE-VIAL       0
# NUM              4
# CODIGO-POSTAL    1
# DISTRITO         0
# COORDENADA-X     0
# COORDENADA-Y     0
# LATITUD          0
# LONGITUD         0
# TIPO             0
# Unnamed: 30      0
# dtype: int64

# %%
centros_medicos['NUMERO'] = centros_medicos['NUM'].fillna(0).astype(np.int64)
centros_medicos['NUMERO'] = centros_medicos['NUMERO'].astype(str)

# %%
centros_medicos['COD_POSTAL'] = centros_medicos['CODIGO-POSTAL'].fillna(0).astype(np.int64)
centros_medicos['COD_POSTAL'] = centros_medicos['COD_POSTAL'].astype(str)

# %%
centros_medicos = centros_medicos.drop(['NUM', 'CODIGO-POSTAL', 'Unnamed: 30'], axis=1)
centros_medicos.head()
# Out:
#                                               NOMBRE       NOMBRE-VIA  \
# 0  Centro Concertado de Atención a las Adicciones...  SANTA HORTENSIA
# 1  Centro Concertado de Atención a las Adicciones...         PORTUGAL
# 2  Centro de Atención a las Adicciones (CAD) de A...          CHOPERA
# 3  Centro de Atención a las Adicciones (CAD) de H...           MINAYA
# 4  Centro de Atención a las Adicciones (CAD) de L...         CAMARENA
#
#   CLASE-VIAL    DISTRITO  COORDENADA-X  COORDENADA-Y                 LATITUD  \
# 0      CALLE   CHAMARTIN        443159       4477482  40.446.053.313.442.700
# 1    AVENIDA      LATINA        438577       4474219   4.041.633.059.885.880
# 2      PASEO  ARGANZUELA        440757       4471619   4.039.305.745.803.060
# 3      CALLE   HORTALEZA        446072       4479929  40.468.288.815.918.500
# 4      CALLE      LATINA        435820       4471982   4.039.597.072.367.930
#
#                   LONGITUD                                               TIPO  \
# ...

# %%
centros_medicos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NOMBRE        270 non-null    object
#  1   NOMBRE-VIA    270 non-null    object
#  2   CLASE-VIAL    270 non-null    object
#  3   DISTRITO      270 non-null    object
#  4   COORDENADA-X  270 non-null    int64
#  5   COORDENADA-Y  270 non-null    int64
#  6   LATITUD       270 non-null    object
#  7   LONGITUD      270 non-null    object
#  8   TIPO          270 non-null    object
#  9   NUMERO        270 non-null    object
#  10  COD_POSTAL    270 non-null    object
# dtypes: int64(2), object(9)
# memory usage: 23.3+ KB

# %%
centros_medicos['DIRECCION'] = centros_medicos['CLASE-VIAL'] + ' ' + centros_medicos['NOMBRE-VIA'] + ' ' + centros_medicos['NUMERO']

# %%
centros_medicos = centros_medicos.drop(['NOMBRE-VIA', 'CLASE-VIAL', 'NUMERO'], axis=1)
centros_medicos.head()
# Out:
#                                               NOMBRE    DISTRITO  \
# 0  Centro Concertado de Atención a las Adicciones...   CHAMARTIN
# 1  Centro Concertado de Atención a las Adicciones...      LATINA
# 2  Centro de Atención a las Adicciones (CAD) de A...  ARGANZUELA
# 3  Centro de Atención a las Adicciones (CAD) de H...   HORTALEZA
# 4  Centro de Atención a las Adicciones (CAD) de L...      LATINA
#
#    COORDENADA-X  COORDENADA-Y                 LATITUD  \
# 0        443159       4477482  40.446.053.313.442.700
# 1        438577       4474219   4.041.633.059.885.880
# 2        440757       4471619   4.039.305.745.803.060
# 3        446072       4479929  40.468.288.815.918.500
# 4        435820       4471982   4.039.597.072.367.930
#
#                   LONGITUD                                               TIPO  \
# 0  -36.702.766.124.516.500  /contenido/entidadesYorganismos/CentrosAtencio...
# 1  -37.239.914.257.003.300  /contenido/entidadesYorganismos/CentrosAtencio...
# ...

# %%
centros_medicos_clean = centros_medicos.reindex(columns=['NOMBRE','DIRECCION','DISTRITO','COD_POSTAL','COORDENADA-X', 'COORDENADA-Y', 'LATITUD', 'LONGITUD', 'TIPO'])
centros_medicos_clean.head()
# Out:
#                                               NOMBRE                DIRECCION  \
# 0  Centro Concertado de Atención a las Adicciones...  CALLE SANTA HORTENSIA 1
# 1  Centro Concertado de Atención a las Adicciones...       AVENIDA PORTUGAL 0
# 2  Centro de Atención a las Adicciones (CAD) de A...         PASEO CHOPERA 12
# 3  Centro de Atención a las Adicciones (CAD) de H...           CALLE MINAYA 7
# 4  Centro de Atención a las Adicciones (CAD) de L...        CALLE CAMARENA 10
#
#      DISTRITO COD_POSTAL  COORDENADA-X  COORDENADA-Y                 LATITUD  \
# 0   CHAMARTIN      28002        443159       4477482  40.446.053.313.442.700
# 1      LATINA      28011        438577       4474219   4.041.633.059.885.880
# 2  ARGANZUELA      28045        440757       4471619   4.039.305.745.803.060
# 3   HORTALEZA      28043        446072       4479929  40.468.288.815.918.500
# 4      LATINA      28047        435820       4471982   4.039.597.072.367.930
#
# ...

# %% [markdown]
# ###  LATITUD Y LONGITUD
# Como podemos observar la latitud y longitud tiene una sintaxis NO válida para a posteriori plotear mapas y calcular distancias por lo que ahora necesitamos:
#
# 1. Eliminar todos los caratares(puntos) que haya entre medias de los numero que forman la longitud y latitud
#
# 2. Y luego, añadirle un punto entre la segunda posicion y tercera posicion de cada elemeno de la columna de Longitud y Latitud
#
#    * ¡OJO! En la losngitud el simbolo menos (-) es necesario y cuenta como una posicion
#
#
# 3. Convertiremos estas dos columas a intengers para tener acabada nuestro análisis y limpieza de nuestro csv de centros medicos en madrid

# %% [markdown]
# A) LATITUD

# %%
centros_medicos_clean['LATITUD'] = centros_medicos_clean['LATITUD'].str.replace('.', '')

# %%
centros_medicos_clean['LATITUD'] = centros_medicos_clean['LATITUD'].apply(lambda x: x[:2] + '.' + x[2:])
centros_medicos_clean['LATITUD']
# Out:
# 0      40.446053313442700
# 1       40.41633059885880
# 2       40.39305745803060
# 3      40.468288815918500
# 4       40.39597072367930
#               ...
# 265     40.47277245807720
# 266     40.46548064796590
# 267     40.42054836583690
# 268    40.428976927386800
# 269    40.449787026276600
# Name: LATITUD, Length: 270, dtype: object

# %% [markdown]
# B) LONGITUD

# %%
centros_medicos_clean['LONGITUD'] = centros_medicos_clean['LONGITUD'].str.replace('.', '')

# %%
centros_medicos_clean['LONGITUD'] = centros_medicos_clean['LONGITUD'].apply(lambda x: x[:2] + '.' + x[2:])
centros_medicos_clean['LONGITUD']
# Out:
# 0      -3.6702766124516500
# 1      -3.7239914257003300
# 2      -3.6980673403694100
# 3       -3.636150078507100
# 4      -3.7562716852987800
#               ...
# 265      -3.71813267268184
# 266    -3.6936383781020600
# 267    -3.7179660205926200
# 268    -3.6721607026353800
# 269     -3.651729403937950
# Name: LONGITUD, Length: 270, dtype: object

# %% [markdown]
# ###  TIPO
# Los tipos de centros medicos si nos damos cuenta son nombres muy largos, por lo que vamos a inspeccionar un poco sobre ellos y ver si podemos acortarlos de alguna manera para poder diferenciarlos mejor.

# %%
centros_medicos_clean['TIPO']
# Out:
# 0      /contenido/entidadesYorganismos/CentrosAtencio...
# 1      /contenido/entidadesYorganismos/CentrosAtencio...
# 2      /contenido/entidadesYorganismos/CentrosAtencio...
# 3      /contenido/entidadesYorganismos/CentrosAtencio...
# 4      /contenido/entidadesYorganismos/CentrosAtencio...
#                              ...
# 265    /contenido/entidadesYorganismos/CentrosAtencio...
# 266    /contenido/entidadesYorganismos/CentrosAtencio...
# 267    /contenido/entidadesYorganismos/CentrosAtencio...
# 268    /contenido/entidadesYorganismos/CentrosAtencio...
# 269    /contenido/entidadesYorganismos/CentrosAtencio...
# Name: TIPO, Length: 270, dtype: object

# %%
centros_medicos_clean['TIPO'].unique()
# Out:
# array(['/contenido/entidadesYorganismos/CentrosAtencionMedica/CentrosAsistenciaDrogodependientes',
#        '/contenido/entidadesYorganismos/CentrosAtencionMedica/OtrosCentrosMedicos',
#        '/contenido/entidadesYorganismos/CentrosAtencionMedica/CentrosEspecialidadesMedicas',
#        '/contenido/entidadesYorganismos/CentrosAtencionMedica/CentrosSalud',
#        '/contenido/entidadesYorganismos/CentrosAtencionSocial/CentrosRehabilitacionPsicosocial',
#        '/contenido/entidadesYorganismos/CentrosAtencionMedica/CentrosPrevencionEnfermedades',
#        '/contenido/entidadesYorganismos/CentrosAtencionMedica/CentrosSaludMental',
#        '/contenido/entidadesYorganismos/CentrosAtencionMedica/HospitalesClinicasSanatorios'],
#       dtype=object)

# %% [markdown]
# * Voy a eliminar los primeros 54 caracteres porque en todos son los mismo y asi vamos a poder diferencias mucho mejor los tipos de centros medicos que hay en madrid.

# %%
centros_medicos_clean['TIPO'] = centros_medicos_clean['TIPO'].apply(lambda x: x[54:])
centros_medicos_clean['TIPO']
# Out:
# 0      CentrosAsistenciaDrogodependientes
# 1      CentrosAsistenciaDrogodependientes
# 2      CentrosAsistenciaDrogodependientes
# 3      CentrosAsistenciaDrogodependientes
# 4      CentrosAsistenciaDrogodependientes
#                       ...
# 265                    CentrosSaludMental
# 266                    CentrosSaludMental
# 267    CentrosAsistenciaDrogodependientes
# 268         CentrosPrevencionEnfermedades
# 269          HospitalesClinicasSanatorios
# Name: TIPO, Length: 270, dtype: object

# %%
centros_medicos_clean['TIPO'].unique()
# Out:
# array(['CentrosAsistenciaDrogodependientes', 'OtrosCentrosMedicos',
#        'CentrosEspecialidadesMedicas', 'CentrosSalud',
#        'CentrosRehabilitacionPsicosocial',
#        'CentrosPrevencionEnfermedades', 'CentrosSaludMental',
#        'HospitalesClinicasSanatorios'], dtype=object)

# %%
# Comprobamos si se han cambiado las longitudes y latitudes a como estabamos buscando
centros_medicos_clean.head()
# Out:
#                                               NOMBRE                DIRECCION  \
# 0  Centro Concertado de Atención a las Adicciones...  CALLE SANTA HORTENSIA 1
# 1  Centro Concertado de Atención a las Adicciones...       AVENIDA PORTUGAL 0
# 2  Centro de Atención a las Adicciones (CAD) de A...         PASEO CHOPERA 12
# 3  Centro de Atención a las Adicciones (CAD) de H...           CALLE MINAYA 7
# 4  Centro de Atención a las Adicciones (CAD) de L...        CALLE CAMARENA 10
#
#      DISTRITO COD_POSTAL  COORDENADA-X  COORDENADA-Y             LATITUD  \
# 0   CHAMARTIN      28002        443159       4477482  40.446053313442700
# 1      LATINA      28011        438577       4474219   40.41633059885880
# 2  ARGANZUELA      28045        440757       4471619   40.39305745803060
# 3   HORTALEZA      28043        446072       4479929  40.468288815918500
# 4      LATINA      28047        435820       4471982   40.39597072367930
#
# ...

# %%
# Guardamos centros_medicos_clean.csv en la carpeta de data
centros_medicos_clean.to_csv('../data/centros_medicos_clean.csv')

# %% [markdown]
# ## Farmacias en madrid

# %%
farmacias = pd.read_csv("../data/oficinas_farmacia.csv", encoding='latin-1', sep=';', error_bad_lines=False)
farmacias.head()
# Out:
#    farmacia_nro_soe                titular_nombre direccion_vial_tipo  \
# 0                 2         Amaya Corral Palomino               PLAZA
# 1                 3     Montserrat Gimenez Mestre               CALLE
# 2                 4  Justo Aquilino Corral Aragon               CALLE
# 3                 5       Irene Arroita Del Campo               CALLE
# 4                 6          Esther Sansi Ponsico               PLAZA
#
#   direccion_vial_nombre direccion_vial_nro municipio_nombre  \
# 0       del Dos de Mayo                  6           Madrid
# 1         de Ríos Rosas                 50           Madrid
# 2          de Argensola                 12           Madrid
# 3             de Alcalá                 98           Madrid
# 4            de Salesas                  7           Madrid
#
#    localizacion_coordenada_x  localizacion_coordenada_y
# 0                   440267.0                  4475426.0
# 1                   440954.0                  4477004.0
# ...

# %% [markdown]
# ### Limpieza y análisis general

# %%
farmacias.shape
# Out:
# (2901, 8)

# %%
farmacias.keys()
# Out:
# Index(['farmacia_nro_soe', 'titular_nombre', 'direccion_vial_tipo',
#        'direccion_vial_nombre', 'direccion_vial_nro', 'municipio_nombre',
#        'localizacion_coordenada_x', 'localizacion_coordenada_y'],
#       dtype='object')

# %%
farmacias.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2901 entries, 0 to 2900
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   farmacia_nro_soe           2901 non-null   int64
#  1   titular_nombre             2901 non-null   object
#  2   direccion_vial_tipo        2897 non-null   object
#  3   direccion_vial_nombre      2897 non-null   object
#  4   direccion_vial_nro         2886 non-null   object
#  5   municipio_nombre           2901 non-null   object
#  6   localizacion_coordenada_x  2888 non-null   float64
#  7   localizacion_coordenada_y  2888 non-null   float64
# dtypes: float64(2), int64(1), object(5)
# memory usage: 181.4+ KB

# %%
farmacias.isnull().sum()
# Out:
# farmacia_nro_soe              0
# titular_nombre                0
# direccion_vial_tipo           4
# direccion_vial_nombre         4
# direccion_vial_nro           15
# municipio_nombre              0
# localizacion_coordenada_x    13
# localizacion_coordenada_y    13
# dtype: int64

# %% [markdown]
# * En este caso nuestro dataframe no tiene apenas valores nulos en comparación con la cantidad de filas que tenemos. Por ello vamos a elimanar las columnas que tengas valores nulos.
# * Lo que haremos en vez de eliminar columnas será concatenar las columnas de: 'direccion_vial_tipo', 'direccion_vial_nombre', 'direccion_vial_nro' porque si nos fijamos es el nombre de la calle partida y dividida en 3 columnas.
# * Al juntar estas tres columnas veremos si los valores NAN de las direcciones coinciden con los valores NAN de las columnas de las coordenadas (que son las que necesitamos)
#     - Si estos valores NAN no coincidieraran eliminaremos solamente las filas que contengan valores nulos en las columnas de coordenadas X y coordenadas Y
#
#     - Y, si si coinciden, lo que haremos será eliminar esas filas que al final y al cabo no va a afectar al desarrollo de este proyecto porque son una cantidad insignificante de datos de los cuales nos vamos a poder deshacer.

# %%
farmacias['direccion'] = farmacias['direccion_vial_tipo'] + ' ' + farmacias['direccion_vial_nombre'] + ' ' + farmacias['direccion_vial_nro']

# %%
farmacias = farmacias.drop(['direccion_vial_tipo', 'direccion_vial_nombre', 'direccion_vial_nro', 'farmacia_nro_soe'], axis=1)
farmacias.head()
# Out:
#                  titular_nombre municipio_nombre  localizacion_coordenada_x  \
# 0         Amaya Corral Palomino           Madrid                   440267.0
# 1     Montserrat Gimenez Mestre           Madrid                   440954.0
# 2  Justo Aquilino Corral Aragon           Madrid                   441063.0
# 3       Irene Arroita Del Campo           Madrid                   442754.0
# 4          Esther Sansi Ponsico           Madrid                   441090.0
#
#    localizacion_coordenada_y                direccion
# 0                  4475426.0  PLAZA del Dos de Mayo 6
# 1                  4477004.0   CALLE de Ríos Rosas 50
# 2                  4475193.0    CALLE de Argensola 12
# 3                  4475148.0       CALLE de Alcalá 98
# 4                  4475021.0       PLAZA de Salesas 7

# %%
farmacias = farmacias.reindex(columns=['titular_nombre','direccion','municipio_nombre','localizacion_coordenada_x','localizacion_coordenada_y'])
farmacias.head()
# Out:
#                  titular_nombre                direccion municipio_nombre  \
# 0         Amaya Corral Palomino  PLAZA del Dos de Mayo 6           Madrid
# 1     Montserrat Gimenez Mestre   CALLE de Ríos Rosas 50           Madrid
# 2  Justo Aquilino Corral Aragon    CALLE de Argensola 12           Madrid
# 3       Irene Arroita Del Campo       CALLE de Alcalá 98           Madrid
# 4          Esther Sansi Ponsico       PLAZA de Salesas 7           Madrid
#
#    localizacion_coordenada_x  localizacion_coordenada_y
# 0                   440267.0                  4475426.0
# 1                   440954.0                  4477004.0
# 2                   441063.0                  4475193.0
# 3                   442754.0                  4475148.0
# 4                   441090.0                  4475021.0

# %%
farmacias.isnull().sum()
# Out:
# titular_nombre                0
# direccion                    17
# municipio_nombre              0
# localizacion_coordenada_x    13
# localizacion_coordenada_y    13
# dtype: int64

# %%
# Investigamos en que filas tenemos nuestros valores nulos
nan_rows = farmacias[farmacias.isnull().any(1)]
nan_rows
# Out:
#                            titular_nombre                       direccion  \
# 365                    Juan Gil Rodriguez               AVDA de España 33
# 621                 Carlos Galdon Cabrera                             NaN
# 746                Mª Soledad Garcia Lope        CALLE de Gerardo Diego 4
# 823                 Patricia Garcia Gomez  CALLE del Conde de Peñalver 51
# 861              Miriam Batuecas Mohedano          CALLE de Amado Nervo 4
# 873           María Aurora Martín Pedraza                             NaN
# 972       Santiago Javier Sanchez Serrano                             NaN
# 1152          Carmen Benitez-Donoso Medio     CALLE de María de Maeztu 52
# 1216                     Silvia Gea Barra                             NaN
# 1358               Mª Paz Gonzalez Cuesta                             NaN
# 1581         Almudena Carmen Pastor Lopez                             NaN
# 1682             Rafael Revuelta De Rojas                             NaN
# ...

# %% [markdown]
# * Las únicas filas que vamos a eliminar son aquellas que contengan los valores nulos en las coordenadas ya que es en lo que nos vamos a fijar aposteriori. Porque el no tener la dirección exacta de la las farmacias no nos perjudica al derrallo de este proyecto ya que poseemos sus coordenadas
# * Esto lo haremos de la siguiente manera:

# %%
farmacias_clean = farmacias.dropna(subset=['localizacion_coordenada_x', 'localizacion_coordenada_y'])
farmacias_clean.head()
# Out:
#                  titular_nombre                direccion municipio_nombre  \
# 0         Amaya Corral Palomino  PLAZA del Dos de Mayo 6           Madrid
# 1     Montserrat Gimenez Mestre   CALLE de Ríos Rosas 50           Madrid
# 2  Justo Aquilino Corral Aragon    CALLE de Argensola 12           Madrid
# 3       Irene Arroita Del Campo       CALLE de Alcalá 98           Madrid
# 4          Esther Sansi Ponsico       PLAZA de Salesas 7           Madrid
#
#    localizacion_coordenada_x  localizacion_coordenada_y
# 0                   440267.0                  4475426.0
# 1                   440954.0                  4477004.0
# 2                   441063.0                  4475193.0
# 3                   442754.0                  4475148.0
# 4                   441090.0                  4475021.0

# %%
farmacias_clean.isnull().sum()
# Out:
# titular_nombre                0
# direccion                    17
# municipio_nombre              0
# localizacion_coordenada_x     0
# localizacion_coordenada_y     0
# dtype: int64

# %% [markdown]
# ### Conversion de coordenadas UTM a coordenadas geográficas

# %%
import pyproj
_projections = {}

def unproject(z, l, x, y):
    if z not in _projections:
        _projections[z] = pyproj.Proj(proj='utm', zone=z, ellps='WGS84')
    if l < 'N':
        y -= 10000000
    lng, lat = _projections[z](x, y, inverse=True)
    return (lat, lng)

# %%
x = list(farmacias_clean.localizacion_coordenada_x)
y = list(farmacias_clean.localizacion_coordenada_y)

# %%
lat, lng = unproject(30, "N", x, y)

# %%
lat
# Out:
# [40.42732576755214,
#  40.44159015864691,
#  40.425283566800815,
#  40.42499625604595,
#  40.423736021015685,
#  40.48033217207024,
#  40.42715438430698,
#  40.440944359704474,
#  40.47015953201248,
#  40.451125586657554,
#  40.431886394491066,
#  40.38320286939667,
#  40.40665771428301,
#  40.41902972127504,
#  40.488337431707684,
#  40.439390827259636,
#  40.47327871249653,
#  40.39873789086786,
#  40.43160804265021,
#  40.43470142379098,
#  40.4346698727368,
#  40.30766227970144,
#  40.38126295212405,
#  40.421292068835115,
#  40.39219795893028,
#  40.381566477892015,
#  40.4221913281943,
#  40.54479414961183,
#  40.39920880060571,
#  40.7412893144225,
#  40.42524657197511,
#  40.3997355980977,
#  40.40589276821121,
#  40.401401780627076,
#  40.44149147298918,
#  40.43491305155747,
#  40.43266382647799,
#  40.29990916420958,
#  40.43579427587019,
#  40.383038250486095,
#  40.414326722014906,
#  40.41322086075534,
#  40.42552021830656,
#  40.409186069278064,
#  40.411197355761274,
# ...

# %%
lng
# Out:
# [-3.7041862522231184,
#  -3.6962344605329593,
#  -3.6947813490726555,
#  -3.6748442024512173,
#  -3.694447144944195,
#  -3.733550712728476,
#  -3.534354949041815,
#  -3.6806280563022513,
#  -3.7151085866975655,
#  -3.677381564076322,
#  -3.6782259574250102,
#  -3.4098102362354927,
#  -3.680329688653387,
#  -3.705455289572843,
#  -3.649873375365068,
#  -3.6994071080137965,
#  -3.577826245892963,
#  -3.701578671994659,
#  -3.711057069288305,
#  -3.7031549248138957,
#  -3.681342929639257,
#  -3.7296081336489064,
#  -3.715840569198867,
#  -3.716995550320937,
#  -3.7262779656482725,
#  -3.743410877791436,
#  -3.69961793944032,
#  -3.6290909627362993,
#  -3.6676930530902108,
#  -4.05538023695018,
#  -3.6813185631843273,
#  -3.67162233014084,
#  -3.7116231191470304,
#  -3.6654757039113415,
#  -3.6976601872504142,
#  -3.6949747793648333,
#  -3.704890370166903,
#  -3.752916736641123,
#  -3.672405447770911,
#  -3.7414949635720216,
#  -3.702542042341112,
#  -3.6902020257485826,
# ...

# %%
farmacias_clean['latitud'] = lat
# Out:
# <ipython-input-58-2904bf5916a8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   farmacias_clean['latitud'] = lat

# %%
farmacias_clean['longitud'] = lng
# Out:
# <ipython-input-59-b60a15d02ffa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   farmacias_clean['longitud'] = lng

# %%
farmacias_clean.head()
# Out:
#                  titular_nombre                direccion municipio_nombre  \
# 0         Amaya Corral Palomino  PLAZA del Dos de Mayo 6           Madrid
# 1     Montserrat Gimenez Mestre   CALLE de Ríos Rosas 50           Madrid
# 2  Justo Aquilino Corral Aragon    CALLE de Argensola 12           Madrid
# 3       Irene Arroita Del Campo       CALLE de Alcalá 98           Madrid
# 4          Esther Sansi Ponsico       PLAZA de Salesas 7           Madrid
#
#    localizacion_coordenada_x  localizacion_coordenada_y    latitud  longitud
# 0                   440267.0                  4475426.0  40.427326 -3.704186
# 1                   440954.0                  4477004.0  40.441590 -3.696234
# 2                   441063.0                  4475193.0  40.425284 -3.694781
# 3                   442754.0                  4475148.0  40.424996 -3.674844
# 4                   441090.0                  4475021.0  40.423736 -3.694447

# %% [markdown]
# * Perfecto, ya tendriamos nuestro dataframe de farmcaias limpio y listo para trabjar con él.
# * Lo guardaremos como un csv nuevo en nuestra carpeta de data para poder exportarlo en los siguientes notebooks y trabajar con él. de manera limpia y ordenada
# * Lo guadaremos de la siguinete manera:

# %%
# Guardamos farmacias_clean.csv en la carpeta de data
farmacias_clean.to_csv('../data/farmacias_clean.csv')
